# %%
import requests
import json
# Danish Superliga id: 271
# Scottish Prem id: 501

API_TOKEN = "aQZHSwB6tywsjsL935mqke9oioIjaur7a62fbgKs9cbnNWJj0YHALfBLU2zf"
Danish_SL = 271
Scottish_Prem = 501

# %% [markdown]
# Get all available Seasons

# %%
request = f"https://soccer.sportmonks.com/api/v2.0/seasons?api_token={API_TOKEN}&league={Danish_SL}"
# request = f"https://soccer.sportmonks.com/api/v2.0/fixtures/date/2020-08-02?api_token={API_TOKEN}&leagues=271"
r = requests.get(request)
print(r)
data = r.json()
#print(data)
for x in data['data']:
    print(x)
# Out:
# <Response [200]>
# {'id': 1273, 'name': '2005/2006', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1274, 'name': '2006/2007', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1275, 'name': '2007/2008', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1276, 'name': '2008/2009', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1277, 'name': '2009/2010', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1278, 'name': '2010/2011', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1279, 'name': '2011/2012', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1280, 'name': '2012/2013', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1281, 'name': '2013/2014', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1282, 'name': '2014/2015', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1286, 'name': '2015/2016', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 759, 'name': '2016/2017', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 6361, 'name': '2017/2018', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 12919, 'name': '2018/2019', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 16020, 'name': '2019/2020', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 17328, 'name': '2020/2021', 'league_id': 271, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 18334, 'name': '2021/2022', 'league_id': 271, 'is_current_season': True, 'current_round_id': 246636, 'current_stage_id': 77453568}
# {'id': 1927, 'name': '2005/2006', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1928, 'name': '2006/2007', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1929, 'name': '2007/2008', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1930, 'name': '2008/2009', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1931, 'name': '2009/2010', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1932, 'name': '2010/2011', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1933, 'name': '2011/2012', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1934, 'name': '2012/2013', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1935, 'name': '2013/2014', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1936, 'name': '2014/2015', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1937, 'name': '2015/2016', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 825, 'name': '2016/2017', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 7953, 'name': '2017/2018', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 12963, 'name': '2018/2019', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 16222, 'name': '2019/2020', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 17141, 'name': '2020/2021', 'league_id': 501, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 18369, 'name': '2021/2022', 'league_id': 501, 'is_current_season': True, 'current_round_id': 247439, 'current_stage_id': 77453684}
# {'id': 1951, 'name': '2013/2014', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 1952, 'name': '2014/2015', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 819, 'name': '2015/2016', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 6018, 'name': '2016/2017', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 12764, 'name': '2017/2018', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 15936, 'name': '2018/2019', 'league_id': 513, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 18260, 'name': '2020/2021', 'league_id': 513, 'is_current_season': True, 'current_round_id': None, 'current_stage_id': None}
# {'id': 15949, 'name': '2018/2019', 'league_id': 1659, 'is_current_season': False, 'current_round_id': None, 'current_stage_id': None}
# {'id': 18101, 'name': '2020/2021', 'league_id': 1659, 'is_current_season': True, 'current_round_id': None, 'current_stage_id': None}

# %%
D_first_season = 17328
request = f"https://soccer.sportmonks.com/api/v2.0/rounds/season/{D_first_season}?api_token={API_TOKEN}&include=fixtures"

r = requests.get(request)
print(r)
data = r.json()
game_list = []
for gameday in data["data"]:
    for game in gameday["fixtures"]["data"]:
        print(f"{gameday['name']}, {game['id']}, {game['localteam_id']}, {game['visitorteam_id']}" )
        game_list.append(game['id'])
# Out:
# <Response [200]>
# 1, 16773956, 390, 939
# 1, 16773957, 211, 2356
# 1, 16773958, 2650, 1020
# 1, 16773959, 293, 2394
# 1, 16773960, 1789, 85
# 1, 16773961, 2905, 7466
# 2, 16773962, 939, 2650
# 2, 16773963, 1789, 2394
# 2, 16773964, 85, 293
# 2, 16773965, 2356, 2905
# 2, 16773966, 7466, 390
# 2, 16773967, 1020, 211
# 3, 16773968, 939, 2356
# 3, 16773969, 2905, 1789
# 3, 16773970, 390, 1020
# 3, 16773971, 293, 211
# 3, 16773972, 7466, 85
# 3, 16773973, 2394, 2650
# 4, 16773974, 2356, 293
# 4, 16773975, 1789, 7466
# 4, 16773976, 2650, 390
# 4, 16773977, 1020, 2905
# 4, 16773978, 211, 939
# 4, 16773979, 85, 2394
# 5, 16773981, 939, 1789
# 5, 16773982, 2905, 211
# 5, 16773985, 7466, 2650
# 5, 16773983, 390, 293
# 5, 16773980, 85, 1020
# 5, 16773984, 2394, 2356
# 6, 16773991, 2650, 1789
# 6, 16773986, 293, 939
# 6, 16773989, 211, 2394
# 6, 16773988, 2356, 390
# 6, 16773987, 2905, 85
# 6, 16773990, 1020, 7466
# 7, 16773997, 7466, 2356
# 7, 16773995, 2394, 939
# 7, 16773994, 1789, 211
# 7, 16773992, 85, 2650
# 7, 16773996, 1020, 293
# 7, 16773993, 390, 2905
# 8, 16774000, 2356, 1020
# 8, 16774002, 2394, 7466
# 8, 16774003, 2650, 2905
# 8, 16773998, 293, 1789
# 8, 16773999, 939, 85
# 8, 16774001, 211, 390
# 9, 16774008, 2650, 211
# 9, 16774006, 1789, 390
# 9, 16774007, 1020, 2394
# 9, 16774005, 2905, 939
# 9, 16774009, 7466, 293
# 9, 16774004, 85, 2356
# 10, 16774013, 2356, 1789
# 10, 16774011, 939, 1020
# 10, 16774014, 211, 7466
# 10, 16774012, 390, 85
# 10, 16774015, 2394, 2905
# 10, 16774010, 293, 2650
# 11, 16774019, 1789, 1020
# 11, 16774021, 7466, 939
# 11, 16774018, 390, 2394
# 11, 16774016, 85, 211
# 11, 16774020, 2650, 2356
# 11, 16774017, 2905, 293
# 12, 16774023, 2356, 7466
# 12, 16774025, 211, 2905
# 12, 16774027, 1020, 2650
# 12, 16774026, 2394, 85
# 12, 16774022, 293, 390
# 12, 16774024, 1789, 939
# 13, 16774031, 390, 2356
# 13, 16774033, 2650, 7466
# 13, 16774030, 2905, 1020
# 13, 16774028, 85, 1789
# 13, 16774032, 211, 293
# 13, 16774029, 939, 2394
# 14, 16774035, 2356, 211
# 14, 16774039, 7466, 2905
# 14, 16774036, 1789, 2650
# 14, 16774038, 1020, 85
# 14, 16774034, 939, 390
# 14, 16774037, 2394, 293
# 15, 16774042, 390, 7466
# 15, 16774045, 2394, 1789
# 15, 16774044, 211, 85
# 15, 16774041, 2905, 2650
# 15, 16774040, 293, 1020
# 15, 16774043, 2356, 939
# 16, 16774049, 1020, 2356
# 16, 16774051, 7466, 2394
# 16, 16774050, 2650, 293
# 16, 16774047, 939, 211
# 16, 16774048, 1789, 2905
# 16, 16774046, 85, 390
# 17, 16774056, 1020, 939
# 17, 16774054, 2356, 2394
# 17, 16774055, 211, 1789
# 17, 16774053, 2905, 390
# 17, 16774052, 293, 7466
# 17, 16774057, 2650, 85
# 18, 16774063, 7466, 211
# 18, 16774061, 1789, 2356
# 18, 16774062, 2394, 1020
# 18, 16774058, 85, 2905
# 18, 16774059, 939, 293
# 18, 16774060, 390, 2650
# 19, 16774066, 2905, 2394
# 19, 16774068, 211, 1020
# 19, 16774064, 85, 7466
# 19, 16774067, 390, 1789
# 19, 16774069, 2650, 939
# 19, 16774065, 293, 2356
# 20, 16774072, 2356, 2650
# 20, 16774070, 293, 85
# 20, 16774071, 939, 2905
# 20, 16774073, 2394, 211
# 20, 16774075, 7466, 1789
# 20, 16774074, 1020, 390
# 21, 16774080, 2650, 2394
# 21, 16774078, 390, 211
# 21, 16774081, 7466, 1020
# 21, 16774079, 1789, 293
# 21, 16774076, 85, 939
# 21, 16774077, 2905, 2356
# 22, 16774082, 293, 2905
# 22, 16774083, 939, 7466
# 22, 16774084, 2356, 85
# 22, 16774085, 211, 2650
# 22, 16774086, 2394, 390
# 22, 16774087, 1020, 1789
# 23, 17948766, 2394, 2905
# 23, 17948767, 85, 2356
# 23, 17948768, 939, 293
# 24, 17948769, 2356, 2394
# 24, 17948770, 293, 85
# 24, 17948771, 2905, 939
# 25, 17948772, 85, 2394
# 25, 17948773, 293, 2905
# 25, 17948774, 2356, 939
# 26, 17948775, 2394, 293
# 26, 17948776, 2905, 2356
# 26, 17948777, 939, 85
# 27, 17948778, 293, 2356
# 27, 17948779, 2905, 85
# 27, 17948780, 2394, 939
# 28, 17948781, 2356, 293
# 28, 17948782, 939, 2394
# 28, 17948783, 85, 2905
# 29, 17948784, 2356, 2905
# 29, 17948785, 293, 939
# 29, 17948786, 2394, 85
# 30, 17948787, 939, 2356
# 30, 17948788, 85, 293
# 30, 17948789, 2905, 2394
# 31, 17948790, 2394, 2356
# 31, 17948791, 85, 939
# 31, 17948792, 2905, 293
# 32, 17948793, 293, 2394
# 32, 17948794, 939, 2905
# 32, 17948795, 2356, 85
# 23, 17948796, 211, 1789
# 23, 17948797, 1020, 390
# 23, 17948798, 2650, 7466
# 24, 17952887, 1789, 7466
# 24, 17952888, 390, 211
# 24, 17952889, 2650, 1020
# 25, 17952890, 7466, 1020
# 25, 17952891, 211, 2650
# 25, 17952892, 1789, 390
# 26, 17952893, 2650, 390
# 26, 17952894, 1020, 1789
# 26, 17952895, 7466, 211
# 27, 17952896, 211, 1020
# 27, 17952897, 390, 7466
# 27, 17952898, 1789, 2650
# 28, 17952899, 211, 7466
# 28, 17952900, 1020, 2650
# 28, 17952901, 390, 1789
# 29, 17952902, 1789, 1020
# 29, 17952903, 2650, 211
# 29, 17952904, 7466, 390
# 30, 17952905, 7466, 1789
# 30, 17952906, 1020, 211
# 30, 17952907, 390, 2650
# 31, 17952908, 1020, 7466
# 31, 17952909, 211, 390
# 31, 17952910, 2650, 1789
# 32, 17952911, 390, 1020
# 32, 17952912, 7466, 2650
# 32, 17952913, 1789, 211

# %%
D_first_match = 16773975

request = f"https://soccer.sportmonks.com/api/v2.0/fixtures/{D_first_match}?api_token={API_TOKEN}&include=lineup,substitutions,events"

r = requests.get(request)

print(r)

data = r.json()

print(data)
# Out:
# <Response [200]>
# {'data': {'id': 16773975, 'league_id': 271, 'season_id': 17328, 'stage_id': 77447994, 'round_id': 199450, 'group_id': None, 'aggregate_id': None, 'venue_id': 214349, 'referee_id': 17843, 'localteam_id': 1789, 'visitorteam_id': 7466, 'winner_team_id': 7466, 'weather_report': {'code': 'clouds', 'type': 'scattered clouds', 'icon': 'https://cdn.sportmonks.com/images/weather/03d.png', 'temperature': {'temp': 62.6, 'unit': 'fahrenheit'}, 'temperature_celcius': {'temp': 17, 'unit': 'celcius'}, 'clouds': '40%', 'humidity': '59%', 'pressure': 994, 'wind': {'speed': '14.99 m/s', 'degree': 190}, 'coordinates': {'lat': 55.4, 'lon': 10.39}, 'updated_at': '2020-10-04T13:45:15.165259Z'}, 'commentaries': False, 'attendance': None, 'pitch': None, 'details': None, 'neutral_venue': False, 'winning_odds_calculated': True, 'formations': {'localteam_formation': '4-3-3', 'visitorteam_formation': '4-2-3-1'}, 'scores': {'localteam_score': 0, 'visitorteam_score': 1, 'localteam_pen_score': None, 'visitorteam_pen_score': None, 'ht_score': '0-0', 'ft_score': '0-1', 'et_score': None, 'ps_score': None}, 'time': {'status': 'FT', 'starting_at': {'date_time': '2020-10-04 12:00:00', 'date': '2020-10-04', 'time': '12:00:00', 'timestamp': 1601812800, 'timezone': 'UTC'}, 'minute': 90, 'second': None, 'added_time': None, 'extra_minute': None, 'injury_time': None}, 'coaches': {'localteam_coach_id': 458446, 'visitorteam_coach_id': 1565617}, 'standings': {'localteam_position': 8, 'visitorteam_position': 6}, 'assistants': {'first_assistant_id': 15740, 'second_assistant_id': 34210, 'fourth_official_id': 71284}, 'leg': '1/1', 'colors': {'localteam': {'color': '#0046A8', 'kit_colors': '#0046A8,#F0F0F0,#5B0623,#0A0A0A,#5C8FAE,#FFDF1B,#0046A8'}, 'visitorteam': {'color': '#B20614', 'kit_colors': '#B20614,#B20614,#B20614,#B20614,#5C8FAE,#FFDF1B,#EEEEEE'}}, 'deleted': False, 'is_placeholder': False, 'substitutions': {'data': [{'id': 16773975004, 'team_id': '7466', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 32795609, 'player_in_name': 'W. Faghir', 'player_out_id': 465302, 'player_out_name': 'A. Muçolli', 'minute': 53, 'extra_minute': None, 'injuried': None}, {'id': 16773975005, 'team_id': '7466', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 2510440, 'player_in_name': 'T. Henriksen', 'player_out_id': 9302865, 'player_out_name': 'T. Gundelund', 'minute': 54, 'extra_minute': None, 'injuried': None}, {'id': 16773975006, 'team_id': '1789', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 37503643, 'player_in_name': 'M. Fenger', 'player_out_id': 85950, 'player_out_name': 'M. Opondo', 'minute': 64, 'extra_minute': None, 'injuried': None}, {'id': 16773975007, 'team_id': '7466', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 32470, 'player_in_name': 'A. Milošević', 'player_out_id': 90728, 'player_out_name': 'J. Ojala', 'minute': 65, 'extra_minute': None, 'injuried': None}, {'id': 16773975009, 'team_id': '7466', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 193095, 'player_in_name': 'D. Montiel', 'player_out_id': 50828, 'player_out_name': 'Y. Ramadani', 'minute': 76, 'extra_minute': None, 'injuried': None}, {'id': 16773975010, 'team_id': '7466', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 219543, 'player_in_name': 'Luis Henrique', 'player_out_id': 302358, 'player_out_name': 'Allan Sousa', 'minute': 76, 'extra_minute': None, 'injuried': None}, {'id': 16773975012, 'team_id': '1789', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 118126, 'player_in_name': 'A. Þrándarson', 'player_out_id': 4237060, 'player_out_name': 'E.  Sabbi', 'minute': 84, 'extra_minute': None, 'injuried': None}, {'id': 16773975015, 'team_id': '1789', 'type': 'subst', 'fixture_id': 16773975, 'player_in_id': 37418801, 'player_in_name': 'M. Hyllegaard', 'player_out_id': 84076, 'player_out_name': 'O. Lund', 'minute': 89, 'extra_minute': None, 'injuried': None}, {'id': 16773975016, 'team_id': '1789', 'type': 'subst', 'fixture_id': 16773975, 'player ...

# %%
for x in data["data"]["lineup"]["data"]:
    print(str(x["team_id"]) + " " + str(x["player_id"]) + " " + x["player_name"])
    
print("------------------------------------------")
    
for x in data["data"]["substitutions"]["data"]:
    print("In : " + str(x["team_id"]) + " " + str(x["player_in_id"]) + " " + x["player_in_name"] + " " + str(x["minute"]))
    print("Out: " + str(x["team_id"]) + " " + str(x["player_out_id"]) +  " " + x["player_out_name"] + " " + str(x["minute"]))
    
print("------------------------------------------")    
    
for x in data["data"]["events"]["data"]:
    if x["type"] == "yellowcard":
        print("Yellow: " + str(x["player_id"]) + " " + x["player_name"] + " " + str(x["minute"]))
# Out:
# 390 5740 Lawrence Thomas
# 390 27618 Stefan Gartenmann
# 390 83004 Pierre Kanstrup
# 390 33745 Patrick Banggaard
# 390 84092 Marc Dal Hende
# 390 83588 Rilwan Hassan
# 390 4592182 Victor Ekani
# 390 83373 Mads Albaek
# 390 85996 Alexander Bah
# 390 1525033 Julius Eskesen
# 390 83083 Anders Jacobsen
# 939 82808 Jesper Hansen
# 939 62943 Dion Cools
# 939 83459 Erik Sviatchenko
# 939 61736 Alexander Scholz
# 939 440450 Paulinho
# 939 194768 Jens Cajuste
# 939 537767 Nicolas Madsen
# 939 84620 Anders Dreyer
# 939 70501 Bozhidar Kraev
# 939 84619 Awer Mabil
# 939 190438 Sory Kaba
# ------------------------------------------
# In : 390 263186 H. Wright 63
# Out: 390 1525033 J. Eskesen 63
# In : 939 1548396 Junior Brumado 63
# Out: 939 70501 B. Kraev 63
# In : 939 223604 Evander 67
# Out: 939 537767 N. M. Hautorp Madsen 67
# In : 939 84011 P. Sisto 68
# Out: 939 84620 A. Dreyer 68
# In : 939 23698077 G. Isaksen 78
# Out: 939 84619 A. Mabil 78
# In : 390 84574 R. Vinderslev 79
# Out: 390 83588 R. Hassan 79
# In : 390 82999 J. Absalonsen 84
# Out: 390 83083 A. Jacobsen 84
# ------------------------------------------
# Yellow: 62943 D. Cools 48

# %%
request = f"https://soccer.sportmonks.com/api/v2.0/fixtures/{D_first_match}?api_token={API_TOKEN}&include=corners"

r = requests.get(request)

print(r)

data = r.json()

print(data)
# Out:
# <Response [200]>
# {'data': {'id': 16773956, 'league_id': 271, 'season_id': 17328, 'stage_id': 77447994, 'round_id': 199447, 'group_id': None, 'aggregate_id': None, 'venue_id': 5653, 'referee_id': 15741, 'localteam_id': 390, 'visitorteam_id': 939, 'winner_team_id': 390, 'weather_report': {'code': 'clouds', 'type': 'scattered clouds', 'icon': 'https://cdn.sportmonks.com/images/weather/03n.png', 'temperature': {'temp': 56.8, 'unit': 'fahrenheit'}, 'temperature_celcius': {'temp': 13.8, 'unit': 'celcius'}, 'clouds': '40%', 'humidity': '76%', 'pressure': 1014, 'wind': {'speed': '8.05 m/s', 'degree': 210}, 'coordinates': {'lat': 55.25, 'lon': 9.49}, 'updated_at': '2020-09-11T18:45:06.263245Z'}, 'commentaries': False, 'attendance': None, 'pitch': None, 'details': None, 'neutral_venue': False, 'winning_odds_calculated': True, 'formations': {'localteam_formation': '3-5-2', 'visitorteam_formation': '4-2-3-1'}, 'scores': {'localteam_score': 2, 'visitorteam_score': 0, 'localteam_pen_score': None, 'visitorteam_pen_score': None, 'ht_score': '0-0', 'ft_score': '2-0', 'et_score': None, 'ps_score': None}, 'time': {'status': 'FT', 'starting_at': {'date_time': '2020-09-11 17:00:00', 'date': '2020-09-11', 'time': '17:00:00', 'timestamp': 1599843600, 'timezone': 'UTC'}, 'minute': 90, 'second': None, 'added_time': None, 'extra_minute': None, 'injury_time': None}, 'coaches': {'localteam_coach_id': 459045, 'visitorteam_coach_id': 82974}, 'standings': {'localteam_position': 1, 'visitorteam_position': 12}, 'assistants': {'first_assistant_id': 12105, 'second_assistant_id': 15739, 'fourth_official_id': 14811}, 'leg': '1/1', 'colors': {'localteam': {'color': '#C0D6FE', 'kit_colors': '#C0D6FE,#C0D6FE,#C0D6FE,#C0D6FE,#5C8FAE,#FFDF1B,#F0F0F0'}, 'visitorteam': {'color': '#C40010', 'kit_colors': '#C40010,#C40010,#C40010,#00C1BA,#C40010,#0046A8,#C40010'}}, 'deleted': False, 'is_placeholder': False, 'corners': {'data': [{'id': 1061722911, 'team_id': 939, 'fixture_id': 16773956, 'minute': 6, 'extra_minute': None, 'comment': '1st Corner'}, {'id': 1062431770, 'team_id': 939, 'fixture_id': 16773956, 'minute': 35, 'extra_minute': None, 'comment': '2nd Corner'}, {'id': 1062831833, 'team_id': 939, 'fixture_id': 16773956, 'minute': 45, 'extra_minute': 3, 'comment': '3rd Corner'}, {'id': 1062831775, 'team_id': 939, 'fixture_id': 16773956, 'minute': 45, 'extra_minute': 3, 'comment': 'Race to 3 Corners'}, {'id': 1063561053, 'team_id': 390, 'fixture_id': 16773956, 'minute': 49, 'extra_minute': None, 'comment': '4th Corner'}, {'id': 1064005348, 'team_id': 390, 'fixture_id': 16773956, 'minute': 62, 'extra_minute': None, 'comment': '5th Corner'}, {'id': 1064192672, 'team_id': 939, 'fixture_id': 16773956, 'minute': 67, 'extra_minute': None, 'comment': '6th Corner'}, {'id': 1064350753, 'team_id': 939, 'fixture_id': 16773956, 'minute': 71, 'extra_minute': None, 'comment': '7th Corner'}, {'id': 1064350729, 'team_id': 939, 'fixture_id': 16773956, 'minute': 71, 'extra_minute': None, 'comment': 'Race to 5 Corners'}, {'id': 1064464677, 'team_id': 390, 'fixture_id': 16773956, 'minute': 73, 'extra_minute': None, 'comment': '8th Corner'}, {'id': 1064970884, 'team_id': 390, 'fixture_id': 16773956, 'minute': 86, 'extra_minute': None, 'comment': '9th Corner'}, {'id': 1064995614, 'team_id': 390, 'fixture_id': 16773956, 'minute': 86, 'extra_minute': None, 'comment': '10th Corner'}, {'id': 1065203064, 'team_id': 939, 'fixture_id': 16773956, 'minute': 90, 'extra_minute': 1, 'comment': '11th Corner'}, {'id': 1065233409, 'team_id': 390, 'fixture_id': 16773956, 'minute': 90, 'extra_minute': 2, 'comment': '12th Corner'}]}}, 'meta': {'plans': [{'name': 'Football Free Plan', 'features': 'Standard', 'request_limit': '180,60', 'sport': 'Soccer'}], 'sports': [{'id': 1, 'name': 'Soccer', 'current': True}]}}

# %%
for idx, x in enumerate(data["data"]["corners"]["data"]):
    print("minute: " + str(x["minute"]) + ", corner number: " + str(idx+1) + ", team: " + str(x["team_id"]))
# Out:
# minute: 6, corner number: 1, team: 939
# minute: 35, corner number: 2, team: 939
# minute: 45, corner number: 3, team: 939
# minute: 45, corner number: 4, team: 939
# minute: 49, corner number: 5, team: 390
# minute: 62, corner number: 6, team: 390
# minute: 67, corner number: 7, team: 939
# minute: 71, corner number: 8, team: 939
# minute: 71, corner number: 9, team: 939
# minute: 73, corner number: 10, team: 390
# minute: 86, corner number: 11, team: 390
# minute: 86, corner number: 12, team: 390
# minute: 90, corner number: 13, team: 939
# minute: 90, corner number: 14, team: 390

# %%
request = f"https://soccer.sportmonks.com/api/v2.0/fixtures/{D_first_match}?api_token={API_TOKEN}&include=lineup,substitutions,events,corners"

r = requests.get(request)

print(r)

data = r.json()

#print(data)
print(json.dumps(data, indent=2))

if data['data']['corners']['data']:
    print('corners is empty: skip')
if data['data']['lineup']['data']:
    print('lineup is empty: skip')
# Out:
# <Response [200]>
# {
#   "data": {
#     "id": 16773975,
#     "league_id": 271,
#     "season_id": 17328,
#     "stage_id": 77447994,
#     "round_id": 199450,
#     "group_id": null,
#     "aggregate_id": null,
#     "venue_id": 214349,
#     "referee_id": 17843,
#     "localteam_id": 1789,
#     "visitorteam_id": 7466,
#     "winner_team_id": 7466,
#     "weather_report": {
#       "code": "clouds",
#       "type": "scattered clouds",
#       "icon": "https://cdn.sportmonks.com/images/weather/03d.png",
#       "temperature": {
#         "temp": 62.6,
#         "unit": "fahrenheit"
#       },
#       "temperature_celcius": {
#         "temp": 17,
#         "unit": "celcius"
#       },
#       "clouds": "40%",
#       "humidity": "59%",
#       "pressure": 994,
#       "wind": {
#         "speed": "14.99 m/s",
#         "degree": 190
#       },
#       "coordinates": {
#         "lat": 55.4,
#         "lon": 10.39
#       },
#       "updated_at": "2020-10-04T13:45:15.165259Z"
#     },
#     "commentaries": false,
#     "attendance": null,
#     "pitch": null,
#     "details": null,
#     "neutral_venue": false,
#     "winning_odds_calculated": true,
#     "formations": {
#       "localteam_formation": "4-3-3",
#       "visitorteam_formation": "4-2-3-1"
#     },
#     "scores": {
#       "localteam_score": 0,
#       "visitorteam_score": 1,
#       "localteam_pen_score": null,
#       "visitorteam_pen_score": null,
#       "ht_score": "0-0",
#       "ft_score": "0-1",
#       "et_score": null,
#       "ps_score": null
#     },
#     "time": {
#       "status": "FT",
#       "starting_at": {
#         "date_time": "2020-10-04 12:00:00",
#         "date": "2020-10-04",
#         "time": "12:00:00",
#         "timestamp": 1601812800,
#         "timezone": "UTC"
#       },
#       "minute": 90,
#       "second": null,
#       "added_time": null,
#       "extra_minute": null,
#       "injury_time": null
#     },
#     "coaches": {
#       "localteam_coach_id": 458446,
#       "visitorteam_coach_id": 1565617
#     },
#     "standings": {
#       "localteam_position": 8,
#       "visitorteam_position": 6
#     },
#     "assistants": {
#       "first_assistant_id": 15740,
#       "second_assistant_id": 34210,
#       "fourth_official_id": 71284
#     },
#     "leg": "1/1",
#     "colors": {
#       "localteam": {
#         "color": "#0046A8",
#         "kit_colors": "#0046A8,#F0F0F0,#5B0623,#0A0A0A,#5C8FAE,#FFDF1B,#0046A8"
#       },
#       "visitorteam": {
#         "color": "#B20614",
#         "kit_colors": "#B20614,#B20614,#B20614,#B20614,#5C8FAE,#FFDF1B,#EEEEEE"
#       }
#     },
#     "deleted": false,
#     "is_placeholder": false,
#     "substitutions": {
#       "data": [
#         {
#           "id": 16773975004,
#           "team_id": "7466",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 32795609,
#           "player_in_name": "W. Faghir",
#           "player_out_id": 465302,
#           "player_out_name": "A. Mu\u00e7olli",
#           "minute": 53,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975005,
#           "team_id": "7466",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 2510440,
#           "player_in_name": "T. Henriksen",
#           "player_out_id": 9302865,
#           "player_out_name": "T. Gundelund",
#           "minute": 54,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975006,
#           "team_id": "1789",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 37503643,
#           "player_in_name": "M. Fenger",
#           "player_out_id": 85950,
#           "player_out_name": "M. Opondo",
#           "minute": 64,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975007,
#           "team_id": "7466",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 32470,
#           "player_in_name": "A. Milo\u0161evi\u0107",
#           "player_out_id": 90728,
#           "player_out_name": "J. Ojala",
#           "minute": 65,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975009,
#           "team_id": "7466",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 193095,
#           "player_in_name": "D. Montiel",
#           "player_out_id": 50828,
#           "player_out_name": "Y. Ramadani",
#           "minute": 76,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975010,
#           "team_id": "7466",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 219543,
#           "player_in_name": "Luis Henrique",
#           "player_out_id": 302358,
#           "player_out_name": "Allan Sousa",
#           "minute": 76,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975012,
#           "team_id": "1789",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 118126,
#           "player_in_name": "A. \u00der\u00e1ndarson",
#           "player_out_id": 4237060,
#           "player_out_name": "E.  Sabbi",
#           "minute": 84,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975015,
#           "team_id": "1789",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 37418801,
#           "player_in_name": "M. Hyllegaard",
#           "player_out_id": 84076,
#           "player_out_name": "O. Lund",
#           "minute": 89,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975016,
#           "team_id": "1789",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 119207,
#           "player_in_name": "S. Gu\u00f0johnsen",
#           "player_out_id": 83797,
#           "player_out_name": "T. Kl\u00f8ve",
#           "minute": 89,
#           "extra_minute": null,
#           "injuried": null
#         },
#         {
#           "id": 16773975017,
#           "team_id": "1789",
#           "type": "subst",
#           "fixture_id": 16773975,
#           "player_in_id": 83965,
#           "player_in_name": "R. Johnson",
#           "player_out_id": 25517,
#           "player_out_name": "K. Larsen",
#           "minute": 89,
#           "extra_minute": null,
#           "injuried": null
#         }
#       ]
#     },
#     "corners": {
#       "data": [
#         {
#           "id": 1299321519,
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "minute": 14,
#           "extra_minute": null,
#           "comment": "1st Corner"
#         },
#         {
#           "id": 1299369933,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 17,
#           "extra_minute": null,
#           "comment": "2nd Corner"
#         },
#         {
#           "id": 1299847677,
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "minute": 43,
#           "extra_minute": null,
#           "comment": "3rd Corner"
#         },
#         {
#           "id": 1300782427,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 64,
#           "extra_minute": null,
#           "comment": "4th Corner"
#         },
#         {
#           "id": 1301006787,
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "minute": 72,
#           "extra_minute": null,
#           "comment": "5th Corner"
#         },
#         {
#           "id": 1301006693,
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "minute": 72,
#           "extra_minute": null,
#           "comment": "Race to 3 Corners"
#         },
#         {
#           "id": 1301131862,
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "minute": 76,
#           "extra_minute": null,
#           "comment": "6th Corner"
#         },
#         {
#           "id": 1301257650,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 80,
#           "extra_minute": null,
#           "comment": "7th Corner"
#         },
#         {
#           "id": 1301460282,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 85,
#           "extra_minute": null,
#           "comment": "8th Corner"
#         },
#         {
#           "id": 1301490817,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 85,
#           "extra_minute": null,
#           "comment": "9th Corner"
#         },
#         {
#           "id": 1301490856,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 85,
#           "extra_minute": null,
#           "comment": "Race to 5 Corners"
#         },
#         {
#           "id": 1301834627,
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "minute": 90,
#           "extra_minute": 4,
#           "comment": "10th Corner"
#         }
#       ]
#     },
#     "lineup": {
#       "data": [
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 85808,
#           "player_name": "O. Christensen",
#           "number": 27,
#           "position": "G",
#           "additional_position": null,
#           "formation_position": 1,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 1,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 0
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 33,
#               "accurate_passes": 12,
#               "passes_accuracy": 36,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 0,
#               "won": 0
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 4,
#               "inside_box_saves": 3,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.22"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 84076,
#           "player_name": "O. Lund",
#           "number": 2,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 2,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 5,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 2,
#               "crosses_accuracy": 0,
#               "passes": 27,
#               "accurate_passes": 19,
#               "passes_accuracy": 70,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 14,
#               "won": 10
#             },
#             "other": {
#               "aerials_won": 2,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 3,
#               "blocks": 0,
#               "interceptions": 3,
#               "clearances": 2,
#               "dispossesed": 1,
#               "minutes_played": 89
#             },
#             "rating": "7.33"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 84292,
#           "player_name": "J. Tverskov",
#           "number": 6,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 5,
#           "posx": null,
#           "posy": null,
#           "captain": true,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 3,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 29,
#               "accurate_passes": 24,
#               "passes_accuracy": 82,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 12,
#               "won": 6
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 2,
#               "blocks": 2,
#               "interceptions": 3,
#               "clearances": 3,
#               "dispossesed": 1,
#               "minutes_played": 90
#             },
#             "rating": "6.82"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 25517,
#           "player_name": "K. Larsen",
#           "number": 5,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 4,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 1,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 45,
#               "accurate_passes": 40,
#               "passes_accuracy": 88,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 5,
#               "won": 1
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 1,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 0,
#               "minutes_played": 89
#             },
#             "rating": "7.14"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 150437,
#           "player_name": "J. Skjelvik",
#           "number": 16,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 3,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 0
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 3,
#               "crosses_accuracy": 0,
#               "passes": 30,
#               "accurate_passes": 26,
#               "passes_accuracy": 86,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 3,
#               "won": 2
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 2,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 2,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.02"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 85950,
#           "player_name": "M. Opondo",
#           "number": 25,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 8,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 3,
#               "committed": 0
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 1,
#               "crosses_accuracy": 0,
#               "passes": 12,
#               "accurate_passes": 10,
#               "passes_accuracy": 83,
#               "key_passes": 2
#             },
#             "dribbles": {
#               "attempts": 3,
#               "success": 2,
#               "dribbled_past": 2
#             },
#             "duels": {
#               "total": 9,
#               "won": 6
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 1,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 1,
#               "dispossesed": 0,
#               "minutes_played": 64
#             },
#             "rating": "7.01"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 84444,
#           "player_name": "J. Thomasen",
#           "number": 14,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 7,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 5,
#               "crosses_accuracy": 1,
#               "passes": 39,
#               "accurate_passes": 33,
#               "passes_accuracy": 84,
#               "key_passes": 1
#             },
#             "dribbles": {
#               "attempts": 2,
#               "success": 1,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 8,
#               "won": 5
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 3,
#               "blocks": 2,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.31"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 83797,
#           "player_name": "T. Kl\u00f8ve",
#           "number": 23,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 6,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 3,
#               "committed": 2
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 3,
#               "crosses_accuracy": 1,
#               "passes": 34,
#               "accurate_passes": 25,
#               "passes_accuracy": 73,
#               "key_passes": 1
#             },
#             "dribbles": {
#               "attempts": 3,
#               "success": 2,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 14,
#               "won": 9
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 3,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 0,
#               "dispossesed": 1,
#               "minutes_played": 89
#             },
#             "rating": "7.21"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 4237060,
#           "player_name": "E.  Sabbi",
#           "number": 11,
#           "position": "A",
#           "additional_position": null,
#           "formation_position": 11,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 1
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 5,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 1,
#               "crosses_accuracy": 0,
#               "passes": 17,
#               "accurate_passes": 11,
#               "passes_accuracy": 64,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 3,
#               "success": 3,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 20,
#               "won": 10
#             },
#             "other": {
#               "aerials_won": 2,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 0,
#               "dispossesed": 4,
#               "minutes_played": 84
#             },
#             "rating": "7.12"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 192020,
#           "player_name": "I. Jebali",
#           "number": 7,
#           "position": "A",
#           "additional_position": null,
#           "formation_position": 10,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 1,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 3,
#               "accurate_passes": 0,
#               "passes_accuracy": 0,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 2,
#               "won": 1
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 0,
#               "minutes_played": 22
#             },
#             "rating": "3.82"
#           }
#         },
#         {
#           "team_id": 1789,
#           "fixture_id": 16773975,
#           "player_id": 19979663,
#           "player_name": "M. Fr\u00f8kj\u00e6r-Jensen",
#           "number": 29,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 9,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 2,
#               "committed": 2
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 22,
#               "accurate_passes": 15,
#               "passes_accuracy": 68,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 3,
#               "success": 3,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 9,
#               "won": 6
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 1,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 0,
#               "dispossesed": 1,
#               "minutes_played": 90
#             },
#             "rating": "6.84"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 28498,
#           "player_name": "I. Groothuizen",
#           "number": 21,
#           "position": "G",
#           "additional_position": null,
#           "formation_position": 1,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 0
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 17,
#               "accurate_passes": 14,
#               "passes_accuracy": 82,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 0,
#               "won": 0
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 1,
#               "offsides": 0,
#               "saves": 1,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 2,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.60"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 9302865,
#           "player_name": "T. Gundelund",
#           "number": 14,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 5,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 0
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 2,
#               "crosses_accuracy": 0,
#               "passes": 28,
#               "accurate_passes": 26,
#               "passes_accuracy": 92,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 1,
#               "won": 0
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 1,
#               "minutes_played": 54
#             },
#             "rating": "6.60"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 85539,
#           "player_name": "M. Greve",
#           "number": 15,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 2,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 1
#             },
#             "goals": {
#               "scored": 1,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 57,
#               "accurate_passes": 51,
#               "passes_accuracy": 89,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 3,
#               "won": 2
#             },
#             "other": {
#               "aerials_won": 2,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 2,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.53"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 90728,
#           "player_name": "J. Ojala",
#           "number": 4,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 3,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 3
#             },
#             "cards": {
#               "yellowcards": 1,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 52,
#               "accurate_passes": 44,
#               "passes_accuracy": 84,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 10,
#               "won": 5
#             },
#             "other": {
#               "aerials_won": 4,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 1,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 2,
#               "dispossesed": 0,
#               "minutes_played": 65
#             },
#             "rating": "6.55"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 85953,
#           "player_name": "M. Amundsen",
#           "number": 2,
#           "position": "D",
#           "additional_position": null,
#           "formation_position": 4,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 4
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 8,
#               "crosses_accuracy": 1,
#               "passes": 46,
#               "accurate_passes": 35,
#               "passes_accuracy": 76,
#               "key_passes": 1
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 15,
#               "won": 5
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 4,
#               "blocks": 0,
#               "interceptions": 2,
#               "clearances": 3,
#               "dispossesed": 2,
#               "minutes_played": 90
#             },
#             "rating": "7.30"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 170468,
#           "player_name": "S. Ezatolahi",
#           "number": 6,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 7,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 1,
#               "committed": 3
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 1,
#               "crosses_accuracy": 0,
#               "passes": 63,
#               "accurate_passes": 50,
#               "passes_accuracy": 79,
#               "key_passes": 1
#             },
#             "dribbles": {
#               "attempts": 4,
#               "success": 2,
#               "dribbled_past": 2
#             },
#             "duels": {
#               "total": 18,
#               "won": 9
#             },
#             "other": {
#               "aerials_won": 3,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 3,
#               "blocks": 0,
#               "interceptions": 1,
#               "clearances": 4,
#               "dispossesed": 0,
#               "minutes_played": 90
#             },
#             "rating": "7.31"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 50828,
#           "player_name": "Y. Ramadani",
#           "number": 16,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 8,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 1
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 0,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 67,
#               "accurate_passes": 64,
#               "passes_accuracy": 95,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 2,
#               "success": 1,
#               "dribbled_past": 3
#             },
#             "duels": {
#               "total": 7,
#               "won": 2
#             },
#             "other": {
#               "aerials_won": 1,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 2,
#               "dispossesed": 0,
#               "minutes_played": 76
#             },
#             "rating": "7.05"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 302358,
#           "player_name": "Allan Sousa",
#           "number": 50,
#           "position": "A",
#           "additional_position": null,
#           "formation_position": 10,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 0,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 3,
#               "committed": 1
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 2,
#               "crosses_accuracy": 1,
#               "passes": 19,
#               "accurate_passes": 17,
#               "passes_accuracy": 89,
#               "key_passes": 3
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 0
#             },
#             "duels": {
#               "total": 7,
#               "won": 3
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 0,
#               "dispossesed": 3,
#               "minutes_played": 76
#             },
#             "rating": "6.41"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 83895,
#           "player_name": "J. Schoop",
#           "number": 20,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 6,
#           "posx": null,
#           "posy": null,
#           "captain": true,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 1
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 1,
#               "committed": 4
#             },
#             "cards": {
#               "yellowcards": 1,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 1,
#               "crosses_accuracy": 0,
#               "passes": 27,
#               "accurate_passes": 22,
#               "passes_accuracy": 81,
#               "key_passes": 1
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 2
#             },
#             "duels": {
#               "total": 7,
#               "won": 1
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 1,
#               "dispossesed": 1,
#               "minutes_played": 90
#             },
#             "rating": "6.65"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 465302,
#           "player_name": "A. Mu\u00e7olli",
#           "number": 11,
#           "position": "M",
#           "additional_position": null,
#           "formation_position": 11,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 1,
#               "shots_on_goal": 0
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 2,
#               "committed": 4
#             },
#             "cards": {
#               "yellowcards": 0,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 3,
#               "crosses_accuracy": 0,
#               "passes": 20,
#               "accurate_passes": 14,
#               "passes_accuracy": 70,
#               "key_passes": 0
#             },
#             "dribbles": {
#               "attempts": 0,
#               "success": 0,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 10,
#               "won": 3
#             },
#             "other": {
#               "aerials_won": 0,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 1,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 1,
#               "dispossesed": 2,
#               "minutes_played": 53
#             },
#             "rating": "6.14"
#           }
#         },
#         {
#           "team_id": 7466,
#           "fixture_id": 16773975,
#           "player_id": 53990,
#           "player_name": "R. Dwamena",
#           "number": 8,
#           "position": "A",
#           "additional_position": null,
#           "formation_position": 9,
#           "posx": null,
#           "posy": null,
#           "captain": false,
#           "type": "lineup",
#           "stats": {
#             "shots": {
#               "shots_total": 4,
#               "shots_on_goal": 2
#             },
#             "goals": {
#               "scored": 0,
#               "assists": 0,
#               "conceded": 0,
#               "owngoals": 0
#             },
#             "fouls": {
#               "drawn": 1,
#               "committed": 4
#             },
#             "cards": {
#               "yellowcards": 1,
#               "redcards": 0,
#               "yellowredcards": 0
#             },
#             "passing": {
#               "total_crosses": 0,
#               "crosses_accuracy": 0,
#               "passes": 19,
#               "accurate_passes": 11,
#               "passes_accuracy": 57,
#               "key_passes": 2
#             },
#             "dribbles": {
#               "attempts": 1,
#               "success": 1,
#               "dribbled_past": 1
#             },
#             "duels": {
#               "total": 13,
#               "won": 4
#             },
#             "other": {
#               "aerials_won": 2,
#               "punches": 0,
#               "offsides": 0,
#               "saves": 0,
#               "inside_box_saves": 0,
#               "pen_scored": 0,
#               "pen_missed": 0,
#               "pen_saved": 0,
#               "pen_committed": 0,
#               "pen_won": 0,
#               "hit_woodwork": 0,
#               "tackles": 0,
#               "blocks": 0,
#               "interceptions": 0,
#               "clearances": 1,
#               "dispossesed": 2,
#               "minutes_played": 90
#             },
#             "rating": "6.84"
#           }
#         }
#       ]
#     },
#     "events": {
#       "data": [
#         {
#           "id": 16773975001,
#           "team_id": "1789",
#           "type": "redcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 192020,
#           "player_name": "I. Jebali",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 22,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975002,
#           "team_id": "7466",
#           "type": "yellowcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 53990,
#           "player_name": "R. Dwamena",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 31,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975003,
#           "team_id": "7466",
#           "type": "yellowcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 90728,
#           "player_name": "J. Ojala",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 45,
#           "extra_minute": 3,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975004,
#           "team_id": "7466",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 32795609,
#           "player_name": "W. Faghir",
#           "related_player_id": 465302,
#           "related_player_name": "A. Mu\u00e7olli",
#           "minute": 53,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975005,
#           "team_id": "7466",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 2510440,
#           "player_name": "T. Henriksen",
#           "related_player_id": 9302865,
#           "related_player_name": "T. Gundelund",
#           "minute": 54,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975006,
#           "team_id": "1789",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 37503643,
#           "player_name": "M. Fenger",
#           "related_player_id": 85950,
#           "related_player_name": "M. Opondo",
#           "minute": 64,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975007,
#           "team_id": "7466",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 32470,
#           "player_name": "A. Milo\u0161evi\u0107",
#           "related_player_id": 90728,
#           "related_player_name": "J. Ojala",
#           "minute": 65,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975008,
#           "team_id": "7466",
#           "type": "yellowcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 83895,
#           "player_name": "J. Schoop",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 71,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975009,
#           "team_id": "7466",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 193095,
#           "player_name": "D. Montiel",
#           "related_player_id": 50828,
#           "related_player_name": "Y. Ramadani",
#           "minute": 76,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975010,
#           "team_id": "7466",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 219543,
#           "player_name": "Luis Henrique",
#           "related_player_id": 302358,
#           "related_player_name": "Allan Sousa",
#           "minute": 76,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975011,
#           "team_id": "7466",
#           "type": "yellowcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 219543,
#           "player_name": "Luis Henrique",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 83,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975012,
#           "team_id": "1789",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 118126,
#           "player_name": "A. \u00der\u00e1ndarson",
#           "related_player_id": 4237060,
#           "related_player_name": "E.  Sabbi",
#           "minute": 84,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975013,
#           "team_id": "7466",
#           "type": "yellowcard",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 32470,
#           "player_name": "A. Milo\u0161evi\u0107",
#           "related_player_id": null,
#           "related_player_name": null,
#           "minute": 85,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975014,
#           "team_id": "7466",
#           "type": "goal",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 85539,
#           "player_name": "M. Greve",
#           "related_player_id": 193095,
#           "related_player_name": "D. Montiel",
#           "minute": 86,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": "0-1",
#           "on_pitch": true
#         },
#         {
#           "id": 16773975016,
#           "team_id": "1789",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 119207,
#           "player_name": "S. Gu\u00f0johnsen",
#           "related_player_id": 83797,
#           "related_player_name": "T. Kl\u00f8ve",
#           "minute": 89,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975017,
#           "team_id": "1789",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 83965,
#           "player_name": "R. Johnson",
#           "related_player_id": 25517,
#           "related_player_name": "K. Larsen",
#           "minute": 89,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         },
#         {
#           "id": 16773975015,
#           "team_id": "1789",
#           "type": "substitution",
#           "var_result": null,
#           "fixture_id": 16773975,
#           "player_id": 37418801,
#           "player_name": "M. Hyllegaard",
#           "related_player_id": 84076,
#           "related_player_name": "O. Lund",
#           "minute": 89,
#           "extra_minute": null,
#           "reason": null,
#           "injuried": null,
#           "result": null,
#           "on_pitch": true
#         }
#       ]
#     }
#   },
#   "meta": {
#     "plans": [
#       {
#         "name": "Football Free Plan",
#         "features": "Standard",
#         "request_limit": "180,60",
#         "sport": "Soccer"
#       }
#     ],
#     "sports": [
#       {
#         "id": 1,
#         "name": "Soccer",
#         "current": true
#       }
#     ]
#   }
# }
# corners is empty: skip
# lineup is empty: skip

# %%
localTeam = data['data']['localteam_id']
visitorTeam = data['data']['visitorteam_id']
local_corners = []
visitor_corners = []
players_local = []
players_away = []

for x in data["data"]["corners"]["data"]:
    if(x['comment'][0] == 'R'): continue # skip "Race to Nth Corner events"
    if(x['team_id'] == localTeam): local_corners.append(x['minute']) # add minute of corner to list of corners
    if(x['team_id'] == visitorTeam): visitor_corners.append(x['minute'])

for x in data["data"]["lineup"]["data"]:
    if(x["team_id"] == localTeam): players_local.append([x["player_id"], 0, x['stats']['other']['minutes_played'], False])
    if(x["team_id"] == visitorTeam): players_away.append([x["player_id"], 0, x['stats']['other']['minutes_played'], False])

for x in data["data"]["substitutions"]["data"]:
    if(x["team_id"] == str(localTeam)): players_local.append([x["player_in_id"], x["minute"], 90, True])
    if(x["team_id"] == str(visitorTeam)): players_away.append([x["player_in_id"],x["minute"], 90, True])

# %%
import sqlite3

# %%
con = sqlite3.connect("cI.db")

cur = con.cursor()

# for each match
localTeam = data['data']['localteam_id']
visitorTeam = data['data']['visitorteam_id']
# date to string
date = data['data']['time']['starting_at']['date']
date = date.split('-')
date = date[0] + date[1] + date[2]
print(date)
# add corners!
for x in data["data"]["corners"]["data"]:
    if(x['comment'][0] == 'R'): continue # skip "Race to Nth Corner events"
    team_id = x['team_id'] 
    corner_min = x['minute']
    cur.execute(f"INSERT INTO game (game_id, corner_min, team_id, date) VALUES ({D_first_match},{corner_min},{team_id},{date})")


for x in data["data"]["lineup"]["data"]:
    player_id = x["player_id"]
    home = 0 if x["team_id"] == str(localTeam) else 1
    min_on = 0
    min_off = x['stats']['other']['minutes_played']
    cur.execute(f"INSERT INTO lineup (game_id, player_id, home, min_on, min_off, team_id) VALUES ({D_first_match},{player_id},{home},{min_on},{min_off},{x['team_id']})")

for x in data["data"]["substitutions"]["data"]:
    player_id = x["player_in_id"]
    home = 0 if x["team_id"] == localTeam else 1
    min_on = x["minute"]
    min_off = 90
    cur.execute(f"INSERT INTO lineup (game_id, player_id, home, min_on, min_off, team_id) VALUES ({D_first_match},{player_id},{home},{min_on},{min_off},{x['team_id']})")

con.commit()
# Out:
# 20201004
